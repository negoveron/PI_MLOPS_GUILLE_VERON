# %% [markdown]
# # Modelo de ML

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
'''
Cargo el archivo deperudo en el ETL, solamente las columnas de id y titulo
'''
movies_ml = pd.read_csv("data/movies_depurado.csv", sep=",", usecols=['title', 'id'])
movies_ml.head()
# Out:
#       id                        title
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II

# %%
''' 
controlo el tamaño
'''
movies_ml.shape
# Out:
# (45332, 2)

# %%
''' 
La cantidad de nulos
'''
movies_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45332 entries, 0 to 45331
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      45332 non-null  int64
#  1   title   45332 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 708.4+ KB

# %%
''' 
Elimino nulos
'''
movies_ml.dropna(inplace=True)
movies_ml.shape
# Out:
# (45332, 2)

# %%
''' 
Guardo por si necesito reiniciar el kernel
'''
movies_ml.to_csv(r'data/recomendacion_data.csv', index=False)

# %%
data = pd.read_csv("data/recomendacion_data.csv", sep=",")
data.head()
# Out:
#       id                        title
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II

# %%
# se importa TfidfVectorizer

vec=TfidfVectorizer()

# %%
''' 
Todo el dataset es muy extenso para calcular la matriz de coseno, 
Obtengo un sample del 70% y lo guardo
'''
sample_data = data.sample(frac=0.7)
sample_data.to_csv(r'data/rec_sample_data.csv', index=False)

# %%
sample_data = pd.read_csv("data/rec_sample_data.csv", sep=",")

# %%
''' 
se crea la matriz de vectores
'''
vecs=vec.fit_transform(sample_data["title"].apply(lambda x: np.str_(x)))

# %%
vecs.shape
# Out:
# (31732, 18475)

# %%
''' 
Se calcula la matriz de similitud de coseno
'''
similarity =cosine_similarity(vecs)

# %%
similarity.shape[0]
# Out:
# 31732

# %%
''' 
Se ordenan por score y se elimina el primero que es el mismo
'''
scores=list(enumerate(similarity[1]))
sorted_scores=sorted(scores,key=lambda x:x[1],reverse=True)
sorted_scores=sorted_scores[1:]
movies=[sample_data.iloc[movie[0]]["title"] for movie in sorted_scores]
print(movies)
# Out:
# ['Bio-Dome', "A Day's Pleasure", 'The Pleasure Garden', 'Pleasure Factory', 'Pleasure Cruise', 'The Pleasure Seekers', 'Always for Pleasure', 'The Pleasure of Being Robbed', 'Pleasure or Pain', 'Anna: the Pleasure, the Torment', 'Nana, the True Key of Pleasure', 'Successive Slidings of Pleasure', "Pleasure at Her Majesty's", 'Night of the Day of the Dawn of the Son of the Bride Part 2: In Shocking 2-D', 'The V.I.P.s', 'The U', 'The Man of the Year', 'The City of the Dead', 'The Fall of the House of Usher', 'The Fall of the House of Usher', 'The Fall of the House of Usher', 'End of the Century: The Story of The Ramones', 'Rise of the Planet of the Apes', 'The Lord of the Rings: The Fellowship of the Ring', 'Dawn of the Planet of the Apes', 'The Day of the Beast', 'The Heart of the Game', 'Nausicaä of the Valley of the Wind', 'The Way of the Dragon', 'The Beast of the City', 'The Edge of the World', 'Man of the Story', 'The Call of the Wild', 'The Call of the Wild', 'The Return of the Vampire', 'The First Day of the Rest of Your Life', 'The Age of the Earth', 'The End of the Affair', 'The End of the Affair', 'The End of the Line', 'The Return of the Soldier', 'Man of the House', 'The Kiss of the Vampire', 'In the Heart of the Sea', 'In the Heat of the Night', 'The Center of the World', 'The Worst of Faces of Death', 'The Sex of the Stars', 'The Year of the Tiger', 'The Middle of the World', 'The Eye of the Storm', 'The Adventures of Priscilla, Queen of the Desert', 'The Voice of the Moon', 'The House of the Spirits', 'The Day of the Crows', 'Day of the Dead', 'Day of the Dead', 'The Name of the Rose', 'The End of the Tour', 'The Night of the Hunted', 'The Last of the Finest', 'The Island at the Top of the World', 'The Messenger: The Story of Joan of Arc', 'House of the Dead', 'The Battle of the Damned', 'The End of Love', 'The Tale of the Fox', 'The Children of the Century', 'The Flight of the Eagle', 'Devil of the Desert Against the Son of Hercules', 'In the Shadow of the Sun', 'Images of the World and the Inscription of War', 'The Light at the Edge of the World', 'The Remains of the Day', 'Man of the Year', 'In the Name of the Son', 'The First of the Few', 'The Return of the Musketeers', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Night of the Wild', 'From the Land of the Moon', 'The Curse of the Werewolf', 'The Day of the Owl', 'The Day of the Dolphin', 'War of the Dead', 'The Night of the Iguana', 'In the Name of...', 'The Legend of the Swordsman', 'The Salt of the Earth', 'In the Name of the Father', 'The Extraordinary Adventures of Mr. West in the Land of the Bolsheviks', 'The Phantom of the Opera', 'The Return of the Living Dead', 'Man of the West', 'The Flight of the Phoenix', 'The Night of the Generals', 'The Story of O Part 2', 'The Art of the Steal', 'In the Shadow of the Machine', 'The Last of the Mohicans', 'The Last of the Mohicans', 'Out of the Dark', 'In the Name of the Law', 'The Day of the Jackal', 'The Fury of the Wolf Man', 'The Miracle of the Bells', 'The Return of the War Room', 'The Age of Love', 'The Soul of the Bone', 'Last of the Living', 'End of the World', 'End of the World', 'The Colors of the Mountain', 'The Son of the Sheik', 'The Face of Love', 'The Case of the Black Cat', 'In the Year of the Pig', 'In the Time of the Butterflies', 'In the Dust of the Stars', 'Out of the Blue', 'Out of the Blue', 'Out of the Blue', 'The Dark Side of The Moon', 'Fist of the North Star: The Legend of Kenshiro', 'The War of the Robots', 'The Story of Us', 'Land of the Dead', 'The Expedition to the End of the World', 'The Girl of the Golden West', 'The Things of Love', 'The Toll of the Sea', 'The Third Part of the Night', 'The Sign of the Cross', 'The Art of Love', 'The Best of Me', 'The Last of the High Kings', 'The Day of the Triffids', 'The Day of the Locust', 'The Dark Side of the Sun', 'The Man of My Life', 'The Edge of Love', 'The Passion of the Christ', 'The Plague of the Zombies', 'In The Hand ...

# %%
'''
funcion que devuelve la los titulo ordenados por similitud
'''
def recommend(id):    
    movie_idx=sample_data[sample_data["id"] == id].index.values[0]
    if movie_idx < similarity.shape[0]:
        scores=list(enumerate(similarity[movie_idx]))
        sorted_scores=sorted(scores,key=lambda x:x[1],reverse=True)
        sorted_scores=sorted_scores[1:6]
        movies=[sample_data.iloc[movie[0]]["title"] for movie in sorted_scores]
        return movies
    else:
        return []

# %%
''' 
Funcion que devueve los n mas similares
'''
def recommend_n(movie_list,n):
    first=[]
    count=0
    for movie in movie_list:
        if count > n-1:
            break
        count+=1
        first.append(movie)
    return first

# %%
print(recommend_n(recommend(282084),5))
# Out:
# ['Doug Stanhope: No Place Like Home', "There's No Tomorrow", 'No Place on Earth', 'Road to Utopia', 'Plastic Utopia']

# %%
sample_data.head()
# Out:
#        id                              title
# 0   44357                Seasons of the Year
# 1   43337  Inauguration of the Pleasure Dome
# 2  282084       There's No Place Like Utopia
# 3   17824                     Private Resort
# 4   59115             Quarantine 2: Terminal

# %%
similarity[23576]
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
''' 
Para el servicio se creara una BD con los similares
'''
recom = []
for indice, fila in sample_data.iterrows():
    recom.append({'movie_id':fila.id,'recom':recommend(fila.id)})
    
df_recom = pd.DataFrame(recom)

df_recom.head()
# Out:
#    movie_id                                              recom
# 0     44357  [Seasons, The Four Seasons, Three Seasons, Man...
# 1     43337  [Bio-Dome, A Day's Pleasure, The Pleasure Gard...
# 2    282084  [Doug Stanhope: No Place Like Home, There's No...
# 3     17824  [Last Resort, Private, Hot Resort, Wrong Turn ...
# 4     59115  [Terminal, The Terminal Man, Terminal Island, ...

# %%
df_recom.shape
# Out:
# (31732, 2)

# %%
#guardar como csv
df_recom.to_csv(r'data/recomendacion_db.csv', index=False, sep=";")

# %%
''' 
pruebo la BD de recomendacion
'''
id_movie = 43337
df_recom2 = pd.read_csv("data/recomendacion_db.csv", sep=";",usecols=['movie_id','recom'])

# Filtrar el DataFrame por el movie_id especificado

df_recom2 = df_recom2[df_recom2["movie_id"] == id_movie]["recom"].values[0].strip('[]').replace('"',"'")
print({"recommend":df_recom2})
# Out:
# {'recommend': "'Bio-Dome', 'A Day's Pleasure', 'The Pleasure Garden', 'Pleasure Factory', 'Pleasure Cruise'"}
